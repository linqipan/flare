# %%
import json
import numpy as np
import math

# %%
with open('flaregeometry.oofem','r') as json_file:
    flare = json.load(json_file)
with open('model.dsgn') as wind_file:
    wind_data = json.load(wind_file)
    
mesh_level = {'refine_level':2,'second_order':2, 'min_ele': 0.5}

# %%
class flaregeo(object):
    
    
    def __init__(self):
        self.section_num = {}
        for i in flare['BeamElements']:
            if i['Section'] not in self.section_num:
                self.section_num[i['Section']] = [i['Label']]
            else:
                self.section_num[i['Section']].append(i['Label'])
        self.radius = [wind_data['elementArray'][0]['Af']/2]
        for i in wind_data['elementArray']:
            self.radius.append(i['Af']/2)
        self.thicktype = {}
        for i in flare['BeamSections']:
            if i['Label'] not in self.thicktype:
                self.thicktype[i['Label']] = i['Area']/3.14
        
        self.section_coord = []
        for i in flare['Nodes']:
            self.section_coord.append(i['Coords'][2])
            
### flare geometry ##        
    def flare_geo(self):
        gmshfile = open('flare.geo','w')
        circlenum=1
        for i in range(1,len(self.section_coord)+1):
            
            gmshfile.write('Point(%d) = {0,0,%d,1};\n'%(5*i-4,self.section_coord[i-1])+\
                          'Point(%d) = {%d,0,%d,1};\n'%(5*i-3,self.radius[i-1],self.section_coord[i-1])+\
                          'Point(%d) = {0,%d,%d,1};\n'%(5*i-2,self.radius[i-1],self.section_coord[i-1])+\
                          'Point(%d) = {-%d,0,%d,1};\n'%(5*i-1,self.radius[i-1],self.section_coord[i-1])+\
                          'Point(%d) = {0,-%d,%d,1};\n'%(5*i,self.radius[i-1],self.section_coord[i-1]))
            gmshfile.write('Circle(%d) = {%d, %d, %d};\n'%(circlenum,5*i-3,5*i-4,5*i-2)+\
                          'Circle(%d) = {%d, %d, %d};\n'%(circlenum+1,5*i-2,5*i-4,5*i-1)+\
                          'Circle(%d) = {%d, %d, %d};\n'%(circlenum+2,5*i-1,5*i-4,5*i)+\
                          'Circle(%d) = {%d, %d, %d};\n'%(circlenum+3,5*i,5*i-4,5*i-3))
            circlenum +=4
        for i in range(1,len(self.section_coord)):
            linenum = 4*len(self.section_coord)
            gmshfile.write('Line(%d) = {%d, %d};\n'%(linenum+4*i-3,5*i-3,5*i+2)+\
                          'Line(%d) = {%d, %d};\n'%(linenum+4*i-2,5*i-2,5*i+3)+\
                          'Line(%d) = {%d, %d};\n'%(linenum+4*i-1,5*i-1,5*i+4)+\
                          'Line(%d) = {%d, %d};\n'%(linenum+4*i,5*i,5*i+5))
            
        for i in range(1,len(self.section_coord)):
            linenum = 4*len(self.section_coord)
            gmshfile.write('Line Loop(%d) = {%d, %d, %d, %d};\n'%(4*i-3,4*i-3,linenum+4*i-2,-(4*i+1),-(linenum+4*i-3))+\
                           'Surface(%d) = {%d};\n'%(4*i-3,4*i-3)+\
                           'Line Loop(%d) = {%d, %d, %d, %d};\n'%(4*i-2,4*i-2,linenum+4*i-1,-(4*i+2),-(linenum+4*i-2))+\
                           'Surface(%d) = {%d};\n'%(4*i-2,4*i-2)+\
                           'Line Loop(%d) = {%d, %d, %d, %d};\n'%(4*i-1,4*i-1,linenum+4*i,-(4*i+3),-(linenum+4*i-1))+\
                           'Surface(%d) = {%d};\n'%(4*i-1,4*i-1)+\
                           'Line Loop(%d) = {%d, %d, %d, %d};\n'%(4*i,4*i,linenum+4*i-3,-(4*i+4),-(linenum+4*i))+\
                           'Surface(%d) = {%d};\n'%(4*i,4*i))
            
        ### Physical groups ####    
        for i in self.section_num:
            surface_num =[]
            for j in self.section_num[i]:
                surface_num.extend((4*j-3,4*j-2,4*j-1,4*j))
            surface_str = ", ".join(map(str,surface_num))
            gmshfile.write('Physical Surface("section%s") = {%s};\n'%(str(i),surface_str))
            
        ### wind surface ###
        
        wind_str = ", ".join(map(str,range(1,len(self.section_coord),4)))
        gmshfile.write('Physical Surface("windsurf") = {%s};\n'%wind_str)
        gmshfile.close()
        return 0
    def mesh_refine(self):
        gmshfile = open('flare.geo','a')
        """
        Mesh option:
        1=MeshAdapt, 2=Automatic, 5=Delaunay, 6=Frontal, 7=BAMG, 8=DelQuad

        """
        gmshfile.write('Mesh.SurfaceFaces = 1;\n'+\
                'Mesh.VolumeEdges = 0;\n'+\
                'Mesh.ElementOrder = %d;\n'%mesh_level['second_order'])
            
        if(mesh_level['refine_level'] == 1):
            gmshfile.write('Mesh.OptimizeNetgen = 1;\n'+\
            'Mesh.Algorithm = 2;\n'+\
            'Mesh.Smoothing = 30;\n'+\
            'Mesh.CharacteristicLengthFromCurvature = 0;\n'+\
            'Mesh.CharacteristicLengthFromPoints = 1;\n'+\
            'Mesh.CharacteristicLengthFactor =2;\n'+\
            'Mesh.CharacteristicLengthMax = %.3f;\n'%mesh_level['min_ele'])
        elif (mesh_level['refine_level'] ==2):
             gmshfile.write('Mesh.OptimizeNetgen = 1;\n'+\
            'Mesh.Algorithm = 2;\n'+\
            'Mesh.Smoothing = 50;\n'+\
            'Mesh.CharacteristicLengthFromCurvature = 0;\n'+\
            'Mesh.CharacteristicLengthFromPoints = 1;\n'+\
            'Mesh.CharacteristicLengthFactor =1;\n'+\
            'Mesh.CharacteristicLengthMax = %.3f;\n'%mesh_level['min_ele'])
        else:
            assert(mesh_level['refine_level'] == 0)
            gmshfile.write('Mesh.OptimizeNetgen = 1;\n'+\
            'Mesh.Algorithm = 2;\n'+\
            'Mesh.Smoothing = 50;\n'+\
            'Mesh.CharacteristicLengthFromCurvature = 1;\n'+\
            'Mesh.CharacteristicLengthFromPoints = 0;\n'+\
            'Mesh.CharacteristicLengthFactor =2;\n'+\
            'Mesh.CharacteristicLengthMax = %.3f;\n'%mesh_level['min_ele'])
        gmshfile.write('Mesh 2;\n'+\
                       'Print.Background = 1;\n'+\
                       'BoundingBox;\n'+\
                       'Print "ScreenMesh.png";\n')
        gmshfile.write('Mesh.SaveAll = 1;\n'+\
                       'Mesh.SaveGroupsOfNodes = 1;\n'+\
                       'Save "flare_gmsh_test.inp";\n'+\
                       'Save "flare_gmsh_test.stl";\n'+\
                       'Exit;\n')
        gmshfile.close()
        return

# %%
Atest =flaregeo()
Atest.flare_geo()
Atest.mesh_refine()

# %%
test=[0,10,20,30];diameter={1:20,2:10};section_num=[1,1,2,2]

# %%
    def flare_geo(test,diameter,section_num):
        gmshfile = open('test.geo','w')
        circlenum=1
        for i in range(1,len(test)+1):
            gmshfile.write('Point(%d) = {0,0,%d,1};\n'%(5*i-4,test[i-1])+\
                          'Point(%d) = {%d,0,%d,1};\n'%(5*i-3,diameter[section_num[i-1]],test[i-1])+\
                          'Point(%d) = {0,%d,%d,1};\n'%(5*i-2,diameter[section_num[i-1]],test[i-1])+\
                          'Point(%d) = {-%d,0,%d,1};\n'%(5*i-1,diameter[section_num[i-1]],test[i-1])+\
                          'Point(%d) = {0,-%d,%d,1};\n'%(5*i,diameter[section_num[i-1]],test[i-1]))
            gmshfile.write('Circle(%d) = {%d, %d, %d};\n'%(circlenum,5*i-3,5*i-4,5*i-2)+\
                          'Circle(%d) = {%d, %d, %d};\n'%(circlenum+1,5*i-2,5*i-4,5*i-1)+\
                          'Circle(%d) = {%d, %d, %d};\n'%(circlenum+2,5*i-1,5*i-4,5*i)+\
                          'Circle(%d) = {%d, %d, %d};\n'%(circlenum+3,5*i,5*i-4,5*i-3))
            circlenum +=4
        for i in range(1,len(test)):
            linenum = 4*len(test)
            gmshfile.write('Line(%d) = {%d, %d};\n'%(linenum+4*i-3,5*i-3,5*i+2)+\
                          'Line(%d) = {%d, %d};\n'%(linenum+4*i-2,5*i-2,5*i+3)+\
                          'Line(%d) = {%d, %d};\n'%(linenum+4*i-1,5*i-1,5*i+4)+\
                          'Line(%d) = {%d, %d};\n'%(linenum+4*i,5*i,5*i+5))
            
        for i in range(1,len(test)):
            linenum = 4*len(test)
            gmshfile.write('Line Loop(%d) = {%d, %d, %d, %d};\n'%(4*i-3,4*i-3,linenum+4*i-2,-(4*i+1),-(linenum+4*i-3))+\
                           'Surface(%d) = {%d};\n'%(4*i-3,4*i-3)+\
                           'Line Loop(%d) = {%d, %d, %d, %d};\n'%(4*i-2,4*i-2,linenum+4*i-1,-(4*i+2),-(linenum+4*i-2))+\
                           'Surface(%d) = {%d};\n'%(4*i-2,4*i-2)+\
                           'Line Loop(%d) = {%d, %d, %d, %d};\n'%(4*i-1,4*i-1,linenum+4*i,-(4*i+3),-(linenum+4*i-1))+\
                           'Surface(%d) = {%d};\n'%(4*i-1,4*i-1)+\
                           'Line Loop(%d) = {%d, %d, %d, %d};\n'%(4*i,4*i,linenum+4*i-3,-(4*i+4),-(linenum+4*i))+\
                           'Surface(%d) = {%d};\n'%(4*i,4*i))

        return 0

# %%
flare_geo(test,diameter,section_num)
# Out:
# 0

# %%
flare.keys()
# Out:
# [u'StructuralTemperatureLoad',
#  u'ConstantElementLoad',
#  u'BeamSections',
#  u'Analysis',
#  u'DisplacementBoundaryConditions',
#  u'Nodes',
#  u'DeadWeightLoad',
#  u'BeamElements']

# %%
math.sqrt(flare['BeamSections'][1]['Area']/3.14)
# Out:
# 225.44570631876613

# %%
flare['DeadWeightLoad']
# Out:
# [{u'Components': [0, 0, -10, 0, 0, 0], u'Label': u'DeadWeight'}]

# %%
flare['BeamSections'][0]['MomentOfInertia_z']/flare['BeamSections'][0]['Area']
# Out:
# 1510377.7074285715

# %%
265719524548/175929.1886010284*2
# Out:
# 3020755.4148458876

# %%
flare['BeamSections']
# Out:
# [{u'Area': 175929.1886010284,
#   u'Density': 7850,
#   u'Label': 1,
#   u'MomentOfInertia_x': 265719524548.99005,
#   u'MomentOfInertia_y': 265719524548.99005,
#   u'MomentOfInertia_z': 265719524548.99005,
#   u'PoissonRatio': 0.3,
#   u'ThermalExpansionCoeff': 12.24,
#   u'YoungModulus': 194162.82142857142},
#  {u'Area': 159592.90680236148,
#   u'Density': 7850,
#   u'Label': 2,
#   u'MomentOfInertia_x': 198079662312.45108,
#   u'MomentOfInertia_y': 198079662312.45108,
#   u'MomentOfInertia_z': 198079662312.45108,
#   u'PoissonRatio': 0.3,
#   u'ThermalExpansionCoeff': 12.24,
#   u'YoungModulus': 194162.82142857142},
#  {u'Area': 143256.62500369456,
#   u'Density': 7850,
#   u'Label': 3,
#   u'MomentOfInertia_x': 143018839162.6469,
#   u'MomentOfInertia_y': 143018839162.6469,
#   u'MomentOfInertia_z': 143018839162.6469,
#   u'PoissonRatio': 0.3,
#   u'ThermalExpansionCoeff': 12.24,
#   u'YoungModulus': 194162.82142857142},
#  {u'Area': 143256.62500369456,
#   u'Density': 7850,
#   u'Label': 4,
#   u'MomentOfInertia_x': 143018839162.6469,
#   u'MomentOfInertia_y': 143018839162.6469,
#   u'MomentOfInertia_z': 143018839162.6469,
#   u'PoissonRatio': 0.3,
#   u'ThermalExpansionCoeff': 12.24,
#   u'YoungModulus': 194162.82142857142},
#  {u'Area': 107442.46875277092,
#   u'Density': 7850,
#   u'Label': 5,
#   u'MomentOfInertia_x': 107717451465.52733,
#   u'MomentOfInertia_y': 107717451465.52733,
#   u'MomentOfInertia_z': 107717451465.52733,
#   u'PoissonRatio': 0.3,
#   u'ThermalExpansionCoeff': 12.24,
#   u'YoungModulus': 194162.82142857142}]

# %%
flare['BeamElements']
# Out:
# [{u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare01'],
#   u'Label': 1,
#   u'Nodes': [1, 2],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare02'],
#   u'Label': 2,
#   u'Nodes': [2, 3],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare03'],
#   u'Label': 3,
#   u'Nodes': [3, 4],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare04'],
#   u'Label': 4,
#   u'Nodes': [4, 5],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare05'],
#   u'Label': 5,
#   u'Nodes': [5, 6],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare06'],
#   u'Label': 6,
#   u'Nodes': [6, 7],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare07'],
#   u'Label': 7,
#   u'Nodes': [7, 8],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare08'],
#   u'Label': 8,
#   u'Nodes': [8, 9],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare09'],
#   u'Label': 9,
#   u'Nodes': [9, 10],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare10'],
#   u'Label': 10,
#   u'Nodes': [10, 11],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare11'],
#   u'Label': 11,
#   u'Nodes': [11, 12],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare12'],
#   u'Label': 12,
#   u'Nodes': [12, 13],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare13'],
#   u'Label': 13,
#   u'Nodes': [13, 14],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare14'],
#   u'Label': 14,
#   u'Nodes': [14, 15],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare15'],
#   u'Label': 15,
#   u'Nodes': [15, 16],
#   u'Section': 1,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare16'],
#   u'Label': 16,
#   u'Nodes': [16, 17],
#   u'Section': 2,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare17'],
#   u'Label': 17,
#   u'Nodes': [17, 18],
#   u'Section': 2,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare18'],
#   u'Label': 18,
#   u'Nodes': [18, 19],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare19'],
#   u'Label': 19,
#   u'Nodes': [19, 20],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare20'],
#   u'Label': 20,
#   u'Nodes': [20, 21],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare21'],
#   u'Label': 21,
#   u'Nodes': [21, 22],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare22'],
#   u'Label': 22,
#   u'Nodes': [22, 23],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare23'],
#   u'Label': 23,
#   u'Nodes': [23, 24],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare24'],
#   u'Label': 24,
#   u'Nodes': [24, 25],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare25'],
#   u'Label': 25,
#   u'Nodes': [25, 26],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare26'],
#   u'Label': 26,
#   u'Nodes': [26, 27],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare27'],
#   u'Label': 27,
#   u'Nodes': [27, 28],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare28'],
#   u'Label': 28,
#   u'Nodes': [28, 29],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare29'],
#   u'Label': 29,
#   u'Nodes': [29, 30],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare30'],
#   u'Label': 30,
#   u'Nodes': [30, 31],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare31'],
#   u'Label': 31,
#   u'Nodes': [31, 32],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare32'],
#   u'Label': 32,
#   u'Nodes': [32, 33],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare33'],
#   u'Label': 33,
#   u'Nodes': [33, 34],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare34'],
#   u'Label': 34,
#   u'Nodes': [34, 35],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare35'],
#   u'Label': 35,
#   u'Nodes': [35, 36],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare36'],
#   u'Label': 36,
#   u'Nodes': [36, 37],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare37'],
#   u'Label': 37,
#   u'Nodes': [37, 38],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare38'],
#   u'Label': 38,
#   u'Nodes': [38, 39],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare39'],
#   u'Label': 39,
#   u'Nodes': [39, 40],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare40'],
#   u'Label': 40,
#   u'Nodes': [40, 41],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare41'],
#   u'Label': 41,
#   u'Nodes': [41, 42],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare42'],
#   u'Label': 42,
#   u'Nodes': [42, 43],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare43'],
#   u'Label': 43,
#   u'Nodes': [43, 44],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare44'],
#   u'Label': 44,
#   u'Nodes': [44, 45],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare45'],
#   u'Label': 45,
#   u'Nodes': [45, 46],
#   u'Section': 3,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare46'],
#   u'Label': 46,
#   u'Nodes': [46, 47],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare47'],
#   u'Label': 47,
#   u'Nodes': [47, 48],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare48'],
#   u'Label': 48,
#   u'Nodes': [48, 49],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare49'],
#   u'Label': 49,
#   u'Nodes': [49, 50],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare50'],
#   u'Label': 50,
#   u'Nodes': [50, 51],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare51'],
#   u'Label': 51,
#   u'Nodes': [51, 52],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare52'],
#   u'Label': 52,
#   u'Nodes': [52, 53],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare53'],
#   u'Label': 53,
#   u'Nodes': [53, 54],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare54'],
#   u'Label': 54,
#   u'Nodes': [54, 55],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare55'],
#   u'Label': 55,
#   u'Nodes': [55, 56],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare56'],
#   u'Label': 56,
#   u'Nodes': [56, 57],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare57'],
#   u'Label': 57,
#   u'Nodes': [57, 58],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare58'],
#   u'Label': 58,
#   u'Nodes': [58, 59],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare59'],
#   u'Label': 59,
#   u'Nodes': [59, 60],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare60'],
#   u'Label': 60,
#   u'Nodes': [60, 61],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare61'],
#   u'Label': 61,
#   u'Nodes': [61, 62],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare62'],
#   u'Label': 62,
#   u'Nodes': [62, 63],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare63'],
#   u'Label': 63,
#   u'Nodes': [63, 64],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare64'],
#   u'Label': 64,
#   u'Nodes': [64, 65],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare65'],
#   u'Label': 65,
#   u'Nodes': [65, 66],
#   u'Section': 4,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare66'],
#   u'Label': 66,
#   u'Nodes': [66, 67],
#   u'Section': 5,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare67'],
#   u'Label': 67,
#   u'Nodes': [67, 68],
#   u'Section': 5,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare68'],
#   u'Label': 68,
#   u'Nodes': [68, 69],
#   u'Section': 5,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare69'],
#   u'Label': 69,
#   u'Nodes': [69, 70],
#   u'Section': 5,
#   u'Zaxis': [0, 1, 0]},
#  {u'BodyLoads': [u'DeadWeight'],
#   u'BoundaryLoads': [u'Windload00flare70'],
#   u'Label': 70,
#   u'Nodes': [70, 71],
#   u'Section': 5,
#   u'Zaxis': [0, 1, 0]}]
